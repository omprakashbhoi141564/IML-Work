# %%
import numpy as np
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression Ridge, Lasso
from sklearn.metrics import mean_squared_error

# %%
X =np_array([
    [1,2,10]
    [2,1,12]
    [3,3,9]
    [4,5,11]
    [5,4,13]
    [6,6,8]
    [7,7,7]
    [8,8,14]
])
y=np_array([6,7,2,18,20,24,28,32])
